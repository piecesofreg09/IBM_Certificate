# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
iris = sns.load_dataset('iris')
iris.shape
# Out:
# (150, 5)

# %%
iris.head()
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
clms = iris.columns.tolist()

# %%
indices = iris.index.tolist()

# %%
# we are using the inline backend
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
iris['sepal_length'].plot()
plt.title('Iris Data')
plt.ylabel('Sepal Length')
plt.xlabel('indices')

plt.show()

# %%
np.max(iris['sepal_length'])
# Out:
# 7.9

# %%
np.max(iris['sepal_width'])
# Out:
# 4.4

# %%
stress_point = 20

iris_sepal = pd.DataFrame(iris.loc[:, ['sepal_length', 'sepal_width']])
hue_values = np.ones((iris_sepal.shape[0], 1)) * 20.0
hue_values[stress_point] = 50.0
iris_sepal_hue = pd.DataFrame(hue_values, columns=['hue'])
size_values = (np.ones((iris_sepal.shape[0], 1)) * 20.0) ** 2
size_values[stress_point] = 40.0 ** 2
iris_sepal_size = pd.DataFrame(size_values, columns=['size'])
iris_sepal_complex = pd.concat([iris_sepal, iris_sepal_hue, iris_sepal_size], axis=1)

iris_sepal_complex.loc[19:23]
# Out:
#     sepal_length  sepal_width   hue    size
# 19           5.1          3.8  20.0   400.0
# 20           5.4          3.4  50.0  1600.0
# 21           5.1          3.7  20.0   400.0
# 22           4.6          3.6  20.0   400.0
# 23           5.1          3.3  20.0   400.0

# %%
iris_sepal_complex.plot(kind='scatter', x="sepal_length", y="sepal_width", c='hue', colormap='viridis')
plt.title('Iris Data')
plt.ylabel('Sepal Length')
plt.xlabel('indices')

plt.text(iris_sepal_complex.loc[20, 'sepal_length'], 
         iris_sepal_complex.loc[20, 'sepal_width'], 
         '20-th iris', fontsize=24)

plt.show()

# %%
iris.plot(kind='scatter', x="sepal_length", y="sepal_width", c='petal_length', colormap='viridis')
plt.title('Iris Data')
plt.xlabel('Indices')
plt.ylabel('Sepal Length')


plt.show()

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.shape
# Out:
# (53940, 10)
